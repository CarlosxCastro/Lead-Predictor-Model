# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('LeadsPredictionRawData.csv', sep = ',')
df.head()
# Out:
#    ID City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  Upper_Age  \
# 0   1        C3         3213            Rented          Individual         36
# 1   2        C5         1117             Owned               Joint         75
# 2   3        C5         3732             Owned          Individual         32
# 3   4       C24         4378             Owned               Joint         52
# 4   5        C8         2190            Rented          Individual         44
#
#    Lower_Age Is_Spouse Health Indicator Holding_Policy_Duration  \
# 0         36        No               X1                     14+
# 1         22        No               X2                     NaN
# 2         32        No              NaN                     1.0
# 3         48        No               X1                     14+
# 4         44        No               X2                     3.0
#
#    Holding_Policy_Type  Reco_Policy_Cat  Reco_Policy_Premium  Response
# ...

# %%
#Fill in Null Values of health indicator variable with the mode
df['Health Indicator']=df['Health Indicator'].fillna(df['Health Indicator'].mode()[0])

# %%
correlation = df.corr().round(2)
plt.figure(figsize = (14,7))
sns.heatmap(correlation, annot = True, cmap = 'YlOrBr')
# Out:
# <AxesSubplot:>

# %%
df = df.drop('Upper_Age', 1)
# Out:
# C:\Users\CARLOS\AppData\Local\Temp\ipykernel_5400\986228902.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop('Upper_Age', 1)

# %%
#using Seaborn library to count number of obeservations per category
plt.figure(figsize = (12,12))

plt.subplot(3,1,1)
sns.countplot(x = 'City_Code', hue= 'Response', palette='Set1', data = df)

plt.subplot(3,1,2)
sns.countplot(x = 'Health Indicator', hue= 'Response', palette='Set1', data = df)

plt.subplot(3,1,3)
sns.countplot(x = 'Holding_Policy_Duration', hue= 'Response', palette='Set1', data = df)
# Out:
# <AxesSubplot:xlabel='Holding_Policy_Duration', ylabel='count'>

# %%
#Test Code to Build Random Trees Model
df = df.drop('ID', 1)
# Out:
# C:\Users\CARLOS\AppData\Local\Temp\ipykernel_5400\1471648679.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop('ID', 1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 3>()
#       1 from sklearn.model_selection import train_test_split
# ----> 3 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)
#
# NameError: name 'X' is not defined

# %%
from sklearn.ensemble import RandomForestClassifier
n_estimators = np.array([100])
alg = ['entropy', 'gini']
values_grid = {'n_estimators': n_estimators, 'criterion': alg}

model = RandomForestClassifier()

gridRandomForest = GridSearchCV(estimator = model, param_grid = values_grid, cv = 5)

gridRandomForest.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 8>()
#       4 values_grid = {'n_estimators': n_estimators, 'criterion': alg}
#       6 model = RandomForestClassifier()
# ----> 8 gridRandomForest = GridSearchCV(estimator = model, param_grid = values_grid, cv = 5)
#      10 gridRandomForest.fit(X_train, y_train)
#
# NameError: name 'GridSearchCV' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 import openai
#       2 openai.api_key = "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"
#       4 prompt = ("Build a random trees model in r after with the given data set to predict the probability of response variable being 1"+ df)
#
# ModuleNotFoundError: No module named 'openai'
